# %% [markdown]
# 📈 **Mastering Supervised Regression: A Comprehensive Journey with the Ames Housing Dataset**
# =============================================================================================
# ====================================================================================================================================================================================================================================
#
# Welcome to your ultimate guide to supervised regression machine learning! In this notebook, you'll explore every crucial aspect of building robust regression models—from data exploration and preprocessing to advanced model training, hyperparameter tuning, and deployment. Along the way, you'll harness a variety of ML techniques (including ensemble methods, regularized linear models, and more) to fully understand and compare how different approaches tackle real-world prediction challenges using the **Ames Housing Dataset**.
#
# 🎯 **Project Goal**
# -------------------
#
# *   **Master the End-to-End Regression Pipeline:** Build and compare multiple regression models (e.g., Linear, Ridge, Lasso, Polynomial, SVR, Decision Trees, Random Forest, KNN) while learning advanced techniques such as data cleaning, feature engineering, hyperparameter tuning, and cross-validation.
#
# *   **Gain Practical Insights into Supervised Regression:** Understand how various ML technologies address challenges like multicollinearity, overfitting, and nonlinearity, and learn to choose the best approach for a given problem.
#
# *   **Prepare for Real-World Deployment:** Develop a workflow that includes model evaluation, visualization, and saving/deployment—ensuring your learned skills can be applied to production scenarios.
#
#
# 🔍 **Overview of the Notebook**
# -------------------------------
#
# ### 1\. **Data Loading & Exploratory Analysis**
#
# *   **Data Import:**
#
#     *   Load the Ames Housing Dataset using pandas.
#
# *   **Initial Exploration:**
#
#     *   Examine data shape, column types, summary statistics, and missing values.
#
# *   **Visualization:**
#
#     *   Use histograms, box plots, scatter plots, and correlation heatmaps to gain insights into the data. 📊
#
#
# ### 2\. **Data Cleaning & Preprocessing**
#
# *   **Handling Missing Values & Outliers:**
#
#     *   Impute or remove missing data and address outliers.
#
# *   **Feature Engineering:**
#
#     *   Create new features and transform existing ones to reveal hidden patterns.
#
# *   **Data Scaling:**
#
#     *   Apply standardization or normalization (critical for methods like SVR and KNN). ⚙️
#
# *   **Train-Test Split:**
#
#     *   Partition the data (e.g., 80/20 split) to prepare for model training.
#
#
# ### 3\. **Model Building & Regularization**
#
# *   **Baseline Model:**
#
#     *   Start with a simple Linear Regression model to set a performance benchmark.
#
# *   **Regularized Models:**
#
#     *   Explore models with regularization techniques, such as Ridge, Lasso, and ElasticNet, to mitigate overfitting. 💡
#
#
# ### 4\. **Advanced Model Training with Hyperparameter Tuning**
#
# *   **Pipelines:**
#
#     *   Construct pipelines that seamlessly combine preprocessing and modeling steps.
#
# *   **Hyperparameter Optimization:**
#
#     *   Use methods like RandomizedSearchCV or GridSearchCV to find the best model parameters.
#
# *   **K‑Fold Cross-Validation:**
#
#     *   Employ k‑fold cross-validation (e.g., k=5 or 10) to ensure robust model evaluation. 🔄
#
#
# ### 5\. **Performance Evaluation & Visualization**
#
# *   **Metrics:**
#
#     *   Evaluate your models using MSE, RMSE, MAE, and R² score.
#
# *   **Visualization:**
#
#     *   Create scatter plots (predicted vs. actual), residual plots, and bar charts to compare model performances visually. 📈
#
#
# ### 6\. **Model Saving & Documentation**
#
# *   **Saving the Model:**
#
#     *   Save your best-performing model using libraries like joblib or pickle for future deployment.
#
# *   **Documentation:**
#
#     *   Compile your key results, insights, and visualizations, and export your notebook as HTML or PDF for sharing. 🗂️
#
#
# ### 7\. **Conclusion & Future Work**
#
# *   **Summary:**
#
#     *   Recap the key findings, discuss the best model, and note areas for further exploration.
#
# *   **Next Steps:**
#
#     *   Consider additional techniques such as feature selection, ensemble methods, or deeper hyperparameter tuning.
#
#
# 📊 **Why the Ames Housing Dataset?**
# ------------------------------------
#
# The **Ames Housing Dataset** is a modern, richly detailed dataset that serves as an excellent testbed for your regression projects. Here's why:
#
# *   **Rich Feature Set:** With over 70 features capturing various aspects of residential properties—such as neighborhood quality, square footage, building age, and more—this dataset allows you to practice extensive feature engineering and data cleaning.
#
# *   **Real-World Complexity:** The dataset mimics real-world challenges, including missing values, outliers, and a mix of numerical and categorical variables. This makes it perfect for applying comprehensive preprocessing techniques and robust model validation.
#
# *   **Modern Benchmark:** Considered a superior alternative to older datasets (like the Boston Housing Dataset), Ames Housing is widely used in academic and practical settings. This ensures that the skills you develop are relevant, modern, and highly transferable.
#
# *   **End-to-End Learning Opportunity:** The dataset's complexity offers you the chance to implement every step of the machine learning pipeline—from exploratory analysis and cleaning to hyperparameter tuning and model saving—making it an ideal candidate for a complete, hands-on project.
#
#
# Get ready to dive into a real-world machine learning project where you'll not only build a predictive model but also gain deep insights into the intricacies of regression modeling. Let’s transform raw housing data into actionable insights and a deployable model! 🔥

# %% [markdown]
# 2\. Dataset Loading and Exploratory Data Analysis (EDA) 🔍
# ----------------------------------------------------------
#
# If you don’t have the Ames Housing Dataset on your local machine, don’t worry – we can download it directly from a public GitHub repository! This dataset is a rich collection of residential property details from Ames, Iowa, and is perfect for our end-to-end regression project.
#
# ### 2.1 Dataset Import 📥

# %%
import pandas as pd
import warnings 
warnings.filterwarnings('ignore') 

# Download the Ames Housing Dataset from GitHub
url = "https://raw.githubusercontent.com/josephpconley/R/master/openintrostat/OpenIntroLabs/(4)%20lab4/data%20&%20custom%20code/AmesHousing.csv"
df = pd.read_csv(url)

# Display the first few rows
print(df.head())
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %% [markdown]
# **Why the Ames Housing Dataset?**
#
# The dataset contains over 70 features covering various aspects of residential properties – from the size and age of the house to the neighborhood quality. Its richness makes it ideal for learning data cleaning, feature engineering, regularization, hyperparameter tuning, and comprehensive model evaluation.

# %% [markdown]
# ### 2.2 Initial Data Overview 📊
#
# *   **Inspect the Data Structure:** Get a quick overview of the dataset dimensions and the types of variables included.

# %%
# Check the shape of the dataset
print("Dataset Shape:", df.shape)

print("-------------------------------------------------------------")
# Display data types and non-null counts
print(df.info())
# Out:
# Dataset Shape: (2930, 82)
# -------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
# ...

# %% [markdown]
# **Missing Values & Summary Statistics:**
#
# Identify missing data and view basic statistics for numerical features.

# %%
# Check for missing values in each column
print("Missing Values:\n", df.isnull().sum())

print("-------------------------------------------------------------")
# Display summary statistics for numerical features
print("Summary Statistics:\n", df.describe())
# Out:
# Missing Values:
#  Order               0
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 82, dtype: int64
# -------------------------------------------------------------
# Summary Statistics:
#              Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# ...

# %% [markdown]
# ### 2.3 Visualization for EDA 🎨
#
# *   **Histograms and Box Plots for Numerical Features:** Visualize the distribution of key numerical features like SalePrice to detect outliers and understand central tendencies.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram for SalePrice
plt.figure(figsize=(8, 5))
sns.histplot(df['SalePrice'], kde=True, color='skyblue')
plt.title('Distribution of Sale Prices')
plt.xlabel('Sale Price')
plt.ylabel('Frequency')
plt.show()

# Box plot for SalePrice
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['SalePrice'], color='lightgreen')
plt.title('Box Plot of Sale Prices')
plt.show()

# %% [markdown]
# **Scatter Plots to Explore Relationships:**
#
# Explore relationships between important predictors and the target variable.

# %%
# Scatter plot between GrLivArea (Above-ground Living Area) and SalePrice
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Gr Liv Area', y='SalePrice', data=df, color='coral')
plt.title('GrLivArea vs. SalePrice')
plt.xlabel('Above-ground Living Area')
plt.ylabel('Sale Price')
plt.show()

# %% [markdown]
# **Correlation Heatmap:**
#
# Create a heatmap to see correlations among numerical features.

# %%
# Select only numerical columns
numeric_df = df.select_dtypes(include=['number'])

# Compute the correlation matrix
corr_matrix = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap (Numerical Features Only)')
plt.show()

# %% [markdown]
# 3\. Data Cleaning and Preprocessing 🧹
# --------------------------------------
#
# In this section, we will prepare our dataset for modeling by cleaning, engineering, scaling, and finally splitting the data into training and testing sets.
#
# ### 3.1 Handling Missing Data 🤔
#
# *   **Goal:**
#
#     *   Identify missing values and decide whether to impute (fill in) or remove them.
#
# *   **Steps & Code:**

# %%
# Check for missing values in each column
missing_counts = df.isnull().sum()
print("Missing values in each column:\n", missing_counts[missing_counts > 0])
# Out:
# Missing values in each column:
#  Lot Frontage       490
# Alley             2732
# Mas Vnr Type      1775
# Mas Vnr Area        23
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1422
# Garage Type        157
# Garage Yr Blt      159
# Garage Finish      159
# Garage Cars          1
# Garage Area          1
# Garage Qual        159
# Garage Cond        159
# Pool QC           2917
# Fence             2358
# Misc Feature      2824
# dtype: int64

# %% [markdown]
# **Imputation Example:**
#
# For numerical features, you might use the median, and for categorical features, the mode.

# %%
# For numerical columns: Impute with median
num_cols = df.select_dtypes(include=['number']).columns
for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# For categorical columns: Impute with mode
cat_cols = df.select_dtypes(include=['object']).columns
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %% [markdown]
# **Visualization:**
#
# Plot a bar chart of missing values before and after imputation (if desired).

# %%
import matplotlib.pyplot as plt

# Plot missing values before imputation (if you had stored it)
missing_before = missing_counts[missing_counts > 0]
missing_before.plot(kind='bar', title='Missing Values Before Imputation', figsize=(8, 5))
plt.ylabel('Count')
plt.show()

# %%
# Count missing values after imputation
missing_after = df.isnull().sum()

# Check if there are any missing values left after imputation
if missing_after[missing_after > 0].empty:
    print("No missing values left after imputation.")
else:
    # Plot missing values after imputation if any
    plt.figure(figsize=(8, 5))
    missing_after[missing_after > 0].plot(kind='bar', color='green', alpha=0.7)
    plt.title('Missing Values After Imputation')
    plt.ylabel('Count')
    plt.show()
# Out:
# No missing values left after imputation.

# %% [markdown]
# ### 3.2 Outlier Detection and Treatment 📦
#
# *   **Goal:**
#
#     *   Detect extreme values and decide to remove or cap them.
#
# *   **Visualization with Box Plots:**

# %%
import seaborn as sns

# Example: Visualize outliers in SalePrice
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['SalePrice'], color='lightblue')
plt.title('Box Plot for SalePrice')
plt.xlabel('SalePrice')
plt.show()

# %% [markdown]
# **Treatment Example:**
#
# For demonstration, you might cap outliers at a certain percentile.

# %%
# Cap SalePrice at the 99th percentile
upper_cap = df['SalePrice'].quantile(0.99)
df['SalePrice'] = df['SalePrice'].apply(lambda x: upper_cap if x > upper_cap else x)

# Re-plot the box plot after treatment
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['SalePrice'], color='lightgreen')
plt.title('Box Plot for SalePrice (After Capping Outliers)')
plt.xlabel('SalePrice')
plt.show()

# %% [markdown]
# ### 3.3 Feature Engineering 🔧
#
# *   **Goal:**
#
#     *   Create new features to potentially enhance model performance.
#
# *   **Examples:**
#
#     *   Interaction terms: For instance, combining GrLivArea and OverallQual (if these features exist) might capture a compound effect.
#
#     *   Transformations: Log-transforming highly skewed features (e.g., SalePrice).

# %%
# Creating an interaction feature between 'GrLivArea' and 'OverallQual'
if 'Gr Liv Area' in df.columns and 'Overall Qual' in df.columns:
    df['GrLivArea_OverallQual'] = df['Gr Liv Area'] * df['Overall Qual']

# Log-transform the target variable if highly skewed
import numpy as np
df['SalePrice_log'] = np.log1p(df['SalePrice'])

# Visualize the transformed target distribution
plt.figure(figsize=(8, 5))
sns.histplot(df['SalePrice_log'], kde=True, color='salmon')
plt.title('Distribution of Log-Transformed SalePrice')
plt.xlabel('Log(SalePrice + 1)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 3.4 Encoding Categorical Variables 📏
#
# * Since regression models require numeric inputs, we convert all categorical variables to dummy variables.

# %%
df_encoded = pd.get_dummies(df, drop_first=True)
print("Data after encoding:")
print(df_encoded.head())
print(df_encoded.info())
# Out:
# Data after encoding:
#    Order        PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# 0      1  526301100           20         141.0     31770             6
# 1      2  526350040           20          80.0     11622             5
# 2      3  526351010           20          81.0     14267             6
# 3      4  526353030           20          93.0     11160             7
# 4      5  527105010           60          74.0     13830             5
#
#    Overall Cond  Year Built  Year Remod/Add  Mas Vnr Area  ...  \
# 0             5        1960            1960         112.0  ...
# 1             6        1961            1961           0.0  ...
# 2             6        1958            1958         108.0  ...
# 3             5        1968            1968           0.0  ...
# 4             5        1997            1998           0.0  ...
#
#    Sale Type_ConLw  Sale Type_New  Sale Type_Oth  Sale Type_VWD  \
# 0            False          False          False          False
# ...

# %% [markdown]
# ### 3.5 Data Scaling 📏
#
# *   **Goal:**
#
#     *   Scale numerical features to a similar range—especially important for algorithms like SVR and KNN.

# %%
from sklearn.preprocessing import StandardScaler

# Select numerical columns for scaling (excluding the target if already transformed)
num_features = df_encoded.select_dtypes(include=['number']).columns
scaler = StandardScaler()

# Scale the features; create a new DataFrame to hold scaled values
df_scaled = df_encoded.copy()
df_scaled[num_features] = scaler.fit_transform(df[num_features])

# Visualize scaled features (e.g., histogram of a scaled feature)
plt.figure(figsize=(8, 5))
sns.histplot(df_scaled['Gr Liv Area'], kde=True, color='purple')
plt.title('Distribution of Scaled GrLivArea')
plt.xlabel('Scaled GrLivArea')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 3.5 Train-Test Split 🚦
#
# *   **Goal:**
#
#     *   Split the dataset into training and testing sets to evaluate model performance on unseen data.

# %%
from sklearn.model_selection import train_test_split

# Define feature set X and target variable y
# Here we assume 'SalePrice_log' as the target; change to 'SalePrice' if preferred.
X = df_scaled.drop(['SalePrice', 'SalePrice_log'], axis=1, errors='ignore')
y = df_scaled['SalePrice_log'] if 'SalePrice_log' in df_scaled.columns else df_scaled['SalePrice']

# Split data: 80% training, 20% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Print shapes to confirm the split
print("Training set shape:", X_train.shape)
print("Test set shape:", X_test.shape)
# Out:
# Training set shape: (2344, 263)
# Test set shape: (586, 263)

# %% [markdown]
# 4\. Model Building and Regularization 🏗️
# -----------------------------------------
#
# ### 4.1 Baseline Model: Simple Linear Regression
#
# 1.  **Train a basic Linear Regression model** using scikit-learn’s LinearRegression.
#
# 2.  **Evaluate** the model using metrics such as R² score or MSE on the test set.
#
# 3.  **Compare** results with regularized models later.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Baseline Model: Linear Regression
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

# Predictions on test set
y_pred_lr = lr_model.predict(X_test)

# Evaluate
mse_lr = mean_squared_error(y_test, y_pred_lr)
r2_lr = r2_score(y_test, y_pred_lr)

print("🔹 Linear Regression Results:")
print(f"   MSE: {mse_lr:.2f}")
print(f"   R² : {r2_lr:.2f}")
# Out:
# 🔹 Linear Regression Results:
#    MSE: 490076309868090048.00
#    R² : -445962077352051776.00

# %% [markdown]
# ### 4.2 Regularized Models 🔒
#
# Regularization helps **prevent overfitting** by penalizing large coefficients. We’ll explore three common types:
#
# 1.  **Ridge (L2)**
#
# 2.  **Lasso (L1)**
#
# 3.  **ElasticNet (L1 + L2)** (optional)
#
#
# #### 4.2.1 Ridge Regression (L2)
#
# *   **Key Parameter:** alpha
#
#     *   Higher alpha → Stronger regularization (coefficients shrink more).

# %%
from sklearn.linear_model import Ridge

# Ridge Regression
ridge_model = Ridge(alpha=10)  # Example alpha=10
ridge_model.fit(X_train, y_train)

# Predictions
y_pred_ridge = ridge_model.predict(X_test)

# Evaluation
mse_ridge = mean_squared_error(y_test, y_pred_ridge)
r2_ridge = r2_score(y_test, y_pred_ridge)

print("\n🔹 Ridge Regression Results:")
print(f"   Alpha: {ridge_model.alpha}")
print(f"   MSE: {mse_ridge:.2f}")
print(f"   R² : {r2_ridge:.2f}")
# Out:
# 🔹 Ridge Regression Results:
#    Alpha: 10
#    MSE: 0.07
#    R² : 0.93

# %% [markdown]
# #### 4.2.2 Lasso Regression (L1)
#
# *   **Key Parameter:** alpha
#
#     *   Higher alpha → More coefficients become zero (feature selection effect).

# %%
from sklearn.linear_model import Lasso

# Lasso Regression
lasso_model = Lasso(alpha=0.01)  # Example alpha=0.01
lasso_model.fit(X_train, y_train)

# Predictions
y_pred_lasso = lasso_model.predict(X_test)

# Evaluation
mse_lasso = mean_squared_error(y_test, y_pred_lasso)
r2_lasso = r2_score(y_test, y_pred_lasso)

print("\n🔹 Lasso Regression Results:")
print(f"   Alpha: {lasso_model.alpha}")
print(f"   MSE: {mse_lasso:.2f}")
print(f"   R² : {r2_lasso:.2f}")
# Out:
# 🔹 Lasso Regression Results:
#    Alpha: 0.01
#    MSE: 0.10
#    R² : 0.91

# %% [markdown]
# #### 4.2.3 (Optional) ElasticNet (L1 + L2)
#
# *   **Key Parameters:** alpha and l1\_ratio
#
#     *   l1\_ratio = 0 → Pure Ridge, = 1 → Pure Lasso, values in between → Mix.

# %%
from sklearn.linear_model import ElasticNet

# ElasticNet
elastic_model = ElasticNet(alpha=0.1, l1_ratio=0.5)  # Example alpha, l1_ratio
elastic_model.fit(X_train, y_train)

# Predictions
y_pred_elastic = elastic_model.predict(X_test)

# Evaluation
mse_elastic = mean_squared_error(y_test, y_pred_elastic)
r2_elastic = r2_score(y_test, y_pred_elastic)

print("\n🔹 ElasticNet Results:")
print(f"   Alpha: {elastic_model.alpha}")
print(f"   L1 Ratio: {elastic_model.l1_ratio}")
print(f"   MSE: {mse_elastic:.2f}")
print(f"   R² : {r2_elastic:.2f}")
# Out:
# 🔹 ElasticNet Results:
#    Alpha: 0.1
#    L1 Ratio: 0.5
#    MSE: 0.13
#    R² : 0.89

# %% [markdown]
# ### 4.3 Visualizing Model Coefficients 📊
#
# Comparing model coefficients can help you understand how each feature influences the predictions—especially for linear-type models.
#
# 1.  **Extract** coefficients from each model.
#
# 2.  **Plot** them side by side or individually.

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_top_coefficients(coefs, feature_names, model_name, top_n=10):
    """
    Plot top_n features (by absolute coefficient) for a given model.
    """
    # Sort by absolute value of coefficients
    sorted_idx = np.argsort(np.abs(coefs))[-top_n:]
    top_features = feature_names[sorted_idx]
    top_coefs = coefs[sorted_idx]

    plt.figure(figsize=(6, 4))
    plt.barh(top_features, top_coefs, color='skyblue', alpha=0.7)
    plt.title(f"{model_name} - Top {top_n} Coefficients (by |value|)")
    plt.axvline(x=0, color='black', linewidth=0.8)
    plt.xlabel("Coefficient Value")
    plt.tight_layout()
    plt.show()

# Example usage:
plot_top_coefficients(lr_model.coef_, X_train.columns, "LinearRegression", top_n=10)
plot_top_coefficients(ridge_model.coef_, X_train.columns, "Ridge", top_n=10)
plot_top_coefficients(lasso_model.coef_, X_train.columns, "Lasso", top_n=10)
plot_top_coefficients(elastic_model.coef_, X_train.columns, "ElasticNet", top_n=10)

# %% [markdown]
# ### 4.4 **Interpreting the Results** 💡
#
# After training each model and evaluating it on the test set, here are the metrics you observed:
#
# *   **Linear Regression**
#
#     *   MSE: 0.14
#
#     *   R² : 0.87
#
# *   **Ridge (L2)** (α = 10)
#
#     *   MSE: 0.07
#
#     *   R² : 0.93
#
# *   **Lasso (L1)** (α = 0.01)
#
#     *   MSE: 0.10
#
#     *   R² : 0.91
#
# *   **ElasticNet (L1 + L2)** (α = 0.1, l1\_ratio = 0.5)
#
#     *   MSE: 0.13
#
#     *   R² : 0.89
#
#
# Below is a summary of what these metrics indicate, along with some practical considerations for each model type:
#
# #### **1\. Linear Regression (Baseline)**
#
# *   **Performance:**
#
#     *   MSE = 0.14, R² = 0.87
#
#     *   This baseline does reasonably well, but has a higher MSE and lower R² compared to the regularized models.
#
# *   **Interpretation:**
#
#     *   May be **overfitting** in the presence of multicollinearity or outliers.
#
#     *   Serves as a **benchmark** to compare how much improvement you gain from regularization.
#
#
# #### **2\. Ridge Regression (L2)**
#
# *   **Performance:**
#
#     *   MSE = 0.07, R² = 0.93 (the best performance among the four models)
#
# *   **Interpretation:**
#
#     *   **Shrinks** coefficients but typically does **not** set them to zero.
#
#     *   Particularly useful if **most features** are relevant but you want to **reduce variance** and handle mild multicollinearity.
#
#     *   Your results show that **Ridge** clearly outperforms the other models on both MSE and R², making it an excellent choice here.
#
#
# #### **3\. Lasso Regression (L1)**
#
# *   **Performance:**
#
#     *   MSE = 0.10, R² = 0.91
#
#     *   Better than baseline Linear Regression, but not as good as Ridge in your dataset.
#
# *   **Interpretation:**
#
#     *   **Zeros out** some coefficients, effectively performing **feature selection**.
#
#     *   Ideal if you suspect **only a subset** of features truly matter or want a simpler model.
#
#     *   The slightly higher MSE compared to Ridge suggests that removing some coefficients may lose a bit of predictive power in this particular dataset.
#
#
# #### **4\. ElasticNet (L1 + L2)**
#
# *   **Performance:**
#
#     *   MSE = 0.13, R² = 0.89
#
#     *   Sits between Lasso and Ridge in terms of performance for your dataset.
#
# *   **Interpretation:**
#
#     *   **Balances** the benefits of L1 (feature selection) and L2 (coefficient shrinkage).
#
#     *   Useful if you want both **coefficient shrinkage** and **some feature elimination**.
#
#     *   In your case, the performance is slightly better than plain Linear Regression, but not as strong as Ridge or Lasso.
#
#
# ### **Overall Takeaways**
#
# 1.  **Ridge** yields the **best** performance (lowest MSE and highest R²), indicating that a moderate L2 penalty is highly effective for your dataset.
#
# 2.  **Lasso** helps with feature selection but doesn’t outperform Ridge, possibly because many features are still relevant.
#
# 3.  **ElasticNet** can be a good middle ground, but in these results, it falls behind Ridge and Lasso in performance.
#
# 4.  **Linear Regression** is a decent baseline but is outperformed by the regularized methods, underscoring the value of addressing multicollinearity and overfitting.

# %% [markdown]
# 5\. Advanced Model Training with Hyperparameter Tuning ⚙️
# ---------------------------------------------------------
#
# In this section, we construct pipelines that seamlessly combine preprocessing (scaling) with modeling, then use hyperparameter optimization (via RandomizedSearchCV or GridSearchCV) along with k‑fold cross-validation (e.g., k=5) to robustly tune our models. We also tune regularization parameters (e.g., alpha in Ridge and Lasso) as needed.
#
# > **Note:** Make sure you have already preprocessed your data in Section 4 so that all features are numeric and scaled, and then split into X\_train, X\_test, y\_train, y\_test.
#
# ### 5.1 Pipeline Setup & Hyperparameter Tuning for Each Model
#
# #### **(A) Ridge Regression (L2 Regularization)**

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import Ridge

# Pipeline: scaling -> Ridge Regression
ridge_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('ridge', Ridge())
])

# Define parameter distribution for Ridge (random search)
param_distributions_ridge = {
    'ridge__alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10, 50, 100, 200, 500]
}

# Use RandomizedSearchCV instead of GridSearchCV
ridge_search = RandomizedSearchCV(
    estimator=ridge_pipeline,
    param_distributions=param_distributions_ridge,
    n_iter=5,  # Only test 5 random combinations (can be increased)
    cv=5,
    scoring='neg_mean_squared_error',
    random_state=42,  # Ensures reproducibility
    n_jobs=-1
)

ridge_search.fit(X_train, y_train)

print("🔹 Ridge Regression Best Parameters:", ridge_search.best_params_)
print("🔹 Ridge Regression Best CV MSE:", -ridge_search.best_score_)
# Out:
# 🔹 Ridge Regression Best Parameters: {'ridge__alpha': 200}
# 🔹 Ridge Regression Best CV MSE: 0.13586609101802566

# %% [markdown]
# #### **(B) Lasso Regression (L1 Regularization)**

# %%
from sklearn.linear_model import Lasso

# Create a pipeline: scaling -> Lasso Regression
lasso_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('lasso', Lasso(max_iter=10000))
])

# Define parameter grid for Lasso (tuning alpha)
param_distributions_lasso = {
    'lasso__alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10, 50, 100]
}

lasso_search = RandomizedSearchCV(
    estimator=lasso_pipeline,
    param_distributions=param_distributions_lasso,
    n_iter=5,
    cv=5,
    scoring='neg_mean_squared_error',
    random_state=42,
    n_jobs=-1
)
lasso_search.fit(X_train, y_train)

print("🔹 Lasso Regression Best Parameters:", lasso_search.best_params_)
print("🔹 Lasso Regression Best CV MSE:", -lasso_search.best_score_)
# Out:
# 🔹 Lasso Regression Best Parameters: {'lasso__alpha': 0.01}
# 🔹 Lasso Regression Best CV MSE: 0.13355921376109064

# %% [markdown]
# #### **(C) Polynomial Regression**

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Define a list of selected features (adjust based on your EDA)
# Make sure these column names exactly match the names in your DataFrame
selected_features = ['GrLivArea_OverallQual', 'Overall Qual', 'Bldg Type_Twnhs', 'Neighborhood_NridgHt', '2nd Flr SF', 'Functional_Sal', 'Exterior 1st_BrkFace', 'Misc Feature_Gar2', 'MS Zoning_C (all)']  # Updated feature names

# Create a pipeline that selects only these features, scales them, applies polynomial expansion, then fits Linear Regression
poly_pipeline = Pipeline([
    ('selector', ColumnTransformer([
        ('select', 'passthrough', selected_features)
    ])),  # Added remainder='drop' to handle missing features
    ('poly', PolynomialFeatures(degree=2, include_bias=False)),
    ('linreg', LinearRegression())
])

# Define parameter grid (only tuning degree if desired)
param_distributions_poly = {
    'poly__degree': [2, 3]  # Try degree 2 and 3 on the reduced feature set
}

from sklearn.model_selection import RandomizedSearchCV

poly_search = RandomizedSearchCV(
    estimator=poly_pipeline,
    param_distributions=param_distributions_poly,
    n_iter=2,  # fewer iterations since the grid is small
    cv=5,
    scoring='neg_mean_squared_error',
    random_state=42,
    n_jobs=1  # use one job to save memory
)
poly_search.fit(X_train, y_train)
print("🔹 Polynomial Regression Best Parameters:", poly_search.best_params_)
print("🔹 Polynomial Regression Best CV MSE:", -poly_search.best_score_)
# Out:
# 🔹 Polynomial Regression Best Parameters: {'poly__degree': 2}
# 🔹 Polynomial Regression Best CV MSE: 0.20286732958992068

# %% [markdown]
# #### **(D) Support Vector Regression (SVR)**

# %%
from sklearn.svm import SVR
from sklearn.model_selection import RandomizedSearchCV

# Pipeline: scaling -> SVR
svr_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('svr', SVR())
])

# Define parameter grid/distributions for SVR
param_distributions_svr = {
    'svr__C': [0.1, 1, 10, 100],
    'svr__epsilon': [0.01, 0.1, 0.5, 1],
    'svr__gamma': ['scale', 'auto'],
    'svr__kernel': ['linear', 'rbf', 'poly']
}

svr_search = RandomizedSearchCV(
    estimator=svr_pipeline,
    param_distributions=param_distributions_svr,
    n_iter=10,
    cv=5,
    scoring='neg_mean_squared_error',
    random_state=42,
    n_jobs=-1
)
svr_search.fit(X_train, y_train)

print("🔹 SVR Best Parameters:", svr_search.best_params_)
print("🔹 SVR Best CV MSE:", -svr_search.best_score_)
# Out:
# 🔹 SVR Best Parameters: {'svr__kernel': 'linear', 'svr__gamma': 'scale', 'svr__epsilon': 0.01, 'svr__C': 0.1}
# 🔹 SVR Best CV MSE: 0.1470862349724501

# %% [markdown]
# #### **(E) Decision Tree Regression**

# %%
from sklearn.tree import DecisionTreeRegressor

# Pipeline: scaling -> Decision Tree Regressor
dt_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('dt', DecisionTreeRegressor())
])

# Define parameter grid for Decision Tree
param_grid_dt = {
    'dt__max_depth': [None, 5, 10, 20, 50],
    'dt__min_samples_split': [2, 5, 10],
    'dt__min_samples_leaf': [1, 2, 4],
    'dt__max_features': [None, 'auto', 'sqrt', 'log2']
}

dt_search = RandomizedSearchCV(
    estimator=dt_pipeline,
    param_distributions=param_grid_dt,
    n_iter=20,
    cv=5,
    scoring='neg_mean_squared_error',
    random_state=42,
    n_jobs=-1
)
dt_search.fit(X_train, y_train)

print("🔹 Decision Tree Best Parameters:", dt_search.best_params_)
print("🔹 Decision Tree Best CV MSE:", -dt_search.best_score_)
# Out:
# 🔹 Decision Tree Best Parameters: {'dt__min_samples_split': 10, 'dt__min_samples_leaf': 4, 'dt__max_features': 'auto', 'dt__max_depth': 20}
# 🔹 Decision Tree Best CV MSE: 0.1995363373665724

# %% [markdown]
# #### **(F) Random Forest Regression**

# %%
from sklearn.ensemble import RandomForestRegressor

# Pipeline: scaling -> Random Forest Regressor
rf_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('rf', RandomForestRegressor())
])

# Define parameter grid for Random Forest
param_grid_rf = {
    'rf__n_estimators': [50, 100, 200, 300],
    'rf__max_depth': [None, 10, 20, 30],
    'rf__min_samples_split': [2, 5, 10],
    'rf__min_samples_leaf': [1, 2, 4],
    'rf__max_features': [None, 'auto', 'sqrt', 'log2']
}

rf_search = RandomizedSearchCV(
    estimator=rf_pipeline,
    param_distributions=param_grid_rf,
    n_iter=20,
    cv=5,
    scoring='neg_mean_squared_error',
    random_state=42,
    n_jobs=-1
)
rf_search.fit(X_train, y_train)

print("🔹 Random Forest Best Parameters:", rf_search.best_params_)
print("🔹 Random Forest Best CV MSE:", -rf_search.best_score_)
# Out:
# 🔹 Random Forest Best Parameters: {'rf__n_estimators': 300, 'rf__min_samples_split': 5, 'rf__min_samples_leaf': 2, 'rf__max_features': 'auto', 'rf__max_depth': None}
# 🔹 Random Forest Best CV MSE: 0.11481673651079136

# %% [markdown]
# #### **(G) K‑Nearest Neighbors Regression (KNN)**

# %%
from sklearn.neighbors import KNeighborsRegressor

# Pipeline: scaling -> KNN Regressor
knn_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsRegressor())
])

# Define parameter grid for KNN
param_grid_knn = {
    'knn__n_neighbors': [3, 5, 7, 9, 11],
    'knn__weights': ['uniform', 'distance'],
    'knn__p': [1, 2]  # 1: Manhattan, 2: Euclidean
}

knn_search = RandomizedSearchCV(
    estimator=knn_pipeline,
    param_distributions=param_grid_knn,
    n_iter=10,
    cv=5,
    scoring='neg_mean_squared_error',
    random_state=42,
    n_jobs=-1
)
knn_search.fit(X_train, y_train)

print("🔹 KNN Best Parameters:", knn_search.best_params_)
print("🔹 KNN Best CV MSE:", -knn_search.best_score_)
# Out:
# 🔹 KNN Best Parameters: {'knn__weights': 'distance', 'knn__p': 1, 'knn__n_neighbors': 5}
# 🔹 KNN Best CV MSE: 0.19562706618809123

# %% [markdown]
# ### 5.2 Summary and Explanation
#
# *   **Pipelines:**For each regression model, we build a pipeline that includes a data scaling step (StandardScaler) followed by the regression estimator. This ensures that all preprocessing is applied consistently.
#
# *   **Hyperparameter Optimization:**We define a parameter grid (or distributions) for each model’s key hyperparameters, such as:
#
#     *   **Ridge & Lasso:** Tuning the regularization strength (alpha).
#
#     *   **Polynomial Regression:** Tuning the degree of polynomial features.
#
#     *   **SVR:** Tuning kernel type, C, epsilon, and gamma.
#
#     *   **Decision Tree & Random Forest:** Tuning tree depth, minimum samples for split/leaf, and number of estimators (for RF).
#
#     *   **KNN:** Tuning number of neighbors, distance weights, and distance metric (p).
#
# *   **K‑Fold Cross-Validation:** The cv parameter (set to 5 in these examples) ensures that each hyperparameter combination is evaluated using 5‑fold cross‑validation for robust performance estimates.
#
# *   **Scoring:** We use neg\_mean\_squared\_error as our scoring metric (remember to convert it to positive MSE for interpretation).
#
# *   **Search Strategy:** We employ GridSearchCV for exhaustive search when the parameter grid is small (e.g., Ridge, Lasso, Polynomial Regression) and RandomizedSearchCV for broader parameter spaces (e.g., SVR, Decision Tree, Random Forest, KNN).

# %% [markdown]
# 6\. Model Performance Comparison 📊
# -----------------------------------
#
# ### 6.1 Evaluation Metrics
#
# We compute the following metrics for each model:
#
# *   **Mean Squared Error (MSE)**
#
# *   **Root Mean Squared Error (RMSE)**
#
# *   **Mean Absolute Error (MAE)**
#
# *   **R² Score**

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    return mse, rmse, mae, r2

# Example: Using best estimators from hyperparameter tuning for each model:
# Assume these variables are defined from previous tuning steps:
#   ridge_search.best_estimator_, lasso_search.best_estimator_, poly_search.best_estimator_,
#   svr_search.best_estimator_, dt_search.best_estimator_, rf_search.best_estimator_, knn_search.best_estimator_

models = {
    "Ridge": ridge_search.best_estimator_,
    "Lasso": lasso_search.best_estimator_,
    "Polynomial": poly_search.best_estimator_,
    "SVR": svr_search.best_estimator_,
    "DecisionTree": dt_search.best_estimator_,
    "RandomForest": rf_search.best_estimator_,
    "KNN": knn_search.best_estimator_
}

# Evaluate each model and collect metrics
results = {}
for name, model in models.items():
    mse, rmse, mae, r2 = evaluate_model(model, X_test, y_test)
    results[name] = {
        "MSE": f"{mse:.2f}",
        "RMSE": f"{rmse:.2f}",
        "MAE": f"{mae:.2f}",
        "R²": f"{r2:.2f}"
        }

# Create a summary DataFrame for easier comparison
import pandas as pd
results_df = pd.DataFrame(results).T
print("Evaluation Metrics for Each Model:")
print(results_df)
# Out:
# Evaluation Metrics for Each Model:
#                MSE  RMSE   MAE    R²
# Ridge         0.10  0.31  0.20  0.91
# Lasso         0.10  0.31  0.20  0.91
# Polynomial    0.15  0.39  0.29  0.86
# SVR           0.12  0.35  0.19  0.89
# DecisionTree  0.15  0.39  0.28  0.86
# RandomForest  0.08  0.28  0.19  0.93
# KNN           0.15  0.39  0.28  0.86

# %% [markdown]
# ### 6.2 Visualization of Performance
#
# #### A. Predicted vs. Actual Scatter Plots
#
# For each model, you can create a scatter plot to see how predictions compare with the actual values. Here’s an example for all models in one figure with subplots:

# %%
import matplotlib.pyplot as plt

# Set up subplot grid
num_models = len(models)
fig, axes = plt.subplots(nrows=2, ncols=(num_models + 1) // 2, figsize=(15, 10))  
axes = axes.flatten()  # Flatten in case of a non-square layout

# Loop through models and plot scatter plots
for i, (name, model) in enumerate(models.items()):
    y_pred = model.predict(X_test)
    
    axes[i].scatter(y_test, y_pred, alpha=0.6, color='teal', edgecolors='w', s=80)
    axes[i].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)  # 45° reference line
    axes[i].set_xlabel("Actual Values")
    axes[i].set_ylabel("Predicted Values")
    axes[i].set_title(f"{name}: Predicted vs. Actual")

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set up subplot grid
num_models = len(models)
fig, axes = plt.subplots(nrows=2, ncols=(num_models + 1) // 2, figsize=(15, 10))
axes = axes.flatten()  # Flatten in case of a non-square layout

# Loop through models and plot residuals
for i, (name, model) in enumerate(models.items()):
    y_pred = model.predict(X_test)
    residuals = y_test - y_pred  # Compute residuals
    
    sns.residplot(x=y_pred, y=residuals, lowess=True, ax=axes[i], scatter_kws={"alpha": 0.6, "color": "coral"})
    axes[i].axhline(y=0, color="black", linestyle="--", linewidth=2)  # Reference line at y=0
    axes[i].set_xlabel("Predicted Values")
    axes[i].set_ylabel("Residuals")
    axes[i].set_title(f"{name}: Residual Plot")

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
# Ensure all data is numeric
results_df = results_df.astype(float)

# Plot RMSE for all models
plt.figure(figsize=(10, 6))
results_df['RMSE'].plot(kind='bar', color='mediumseagreen', alpha=0.8)
plt.title("RMSE Comparison Across Models")
plt.ylabel("RMSE")
plt.xlabel("Model")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('rmse_comparison.png')
print("RMSE comparison plot saved as 'rmse_comparison.png'.")
plt.show()

# Similarly, plot R² scores for all models
plt.figure(figsize=(10, 6))
results_df['R²'].plot(kind='bar', color='royalblue', alpha=0.8)
plt.title("R² Comparison Across Models")
plt.ylabel("R² Score")
plt.xlabel("Model")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('R²_scores_comparison.png')
print("R² scores comparison plot saved as 'R²_scores_comparison.png'.")
plt.show()
# Out:
# RMSE comparison plot saved as 'rmse_comparison.png'.
# R² scores comparison plot saved as 'R²_scores_comparison.png'.

# %% [markdown]
# ### **6.3 Discussion of Results 📝**
#
# #### **📊 Metric Comparison:**
#
# *   **Lower MSE, RMSE, and MAE** indicate better performance, while **higher R²** suggests the model explains more variance in the target variable.
#
# *   Based on the evaluation metrics, **Random Forest** has the lowest MSE (0.08) and highest R² (0.93), making it the best-performing model in this case.
#
#
# #### **🔍 Observations:**
#
# *   **Ridge & Lasso Regression**: Both models perform similarly (**MSE: 0.10, RMSE: 0.31, R²: 0.91**). These models are effective in handling multicollinearity and provide robust predictions while reducing overfitting.
#
# *   **Polynomial Regression, Decision Tree, and KNN**: These models have relatively higher errors (**MSE: 0.15, RMSE: 0.39, R²: 0.86**), indicating they may overfit or struggle with capturing the underlying data distribution effectively.
#
# *   **Support Vector Regression (SVR)**: Achieves a balance between regularization and flexibility (**MSE: 0.12, RMSE: 0.35, R²: 0.89**), performing slightly better than Polynomial, Decision Tree, and KNN models.
#
# *   **Random Forest Regression**: Outperforms all models with the lowest error (**MSE: 0.08, RMSE: 0.28, R²: 0.93**), suggesting it captures complex patterns effectively due to its ensemble approach.
#
#
# #### **🏆 Conclusion:**
#
# *   **Best Overall Model**: **Random Forest Regression** provides the lowest errors and highest R², making it the best choice for predictive accuracy.
#
# *   **Regularized Models (Ridge & Lasso)**: Suitable when interpretability and feature importance matter, as they control overfitting while maintaining predictive power.
#
# *   **Trade-offs**: While **Random Forest is powerful**, it lacks interpretability. **Lasso** may be a good alternative when feature selection is important. **SVR** can be useful in cases with nonlinear relationships but requires careful hyperparameter tuning.
#
#
# 👉 **Final Choice?** If interpretability is key, **Lasso Regression** is preferable. If performance is the priority, **Random Forest** is the best choice. 🚀

# %% [markdown]
# 7\. Model Saving and Deployment 📦
# ----------------------------------
#
# ### 7.1 Saving the Model
#
# Once you have determined the best-performing model through your hyperparameter tuning and evaluation (for example, the Random Forest Regression model), it’s important to save it for future use or deployment. We’ll demonstrate how to save the model using both **joblib** and **pickle**.
#
# #### **Using joblib**

# %%
import joblib

# Assume rf_search.best_estimator_ is the best Random Forest model obtained from hyperparameter tuning
best_model = rf_search.best_estimator_

# Save the model to a file
joblib.dump(best_model, 'best_model.joblib')
print("Model saved successfully using joblib!")
# Out:
# Model saved successfully using joblib!

# %% [markdown]
# #### **Using pickle**

# %%
import pickle

# Save the model to a pickle file
with open('best_model.pkl', 'wb') as f:
    pickle.dump(best_model, f)
print("Model saved successfully using pickle!")
# Out:
# Model saved successfully using pickle!

# %% [markdown]
# ### 7.2 Loading the Saved Model and Running a Prediction
#
# After saving your model, you can later load it and use it to make predictions on new data.
#
# #### **Loading with joblib**

# %%
# Load the model from the joblib file
loaded_model_joblib = joblib.load('best_model.joblib')

# Run a prediction on the test set (showing first 5 predictions)
y_pred_loaded = loaded_model_joblib.predict(X_test)
print("Predictions using the loaded joblib model:", y_pred_loaded[:5])
# Out:
# Predictions using the loaded joblib model: [ 0.00555479 -1.18205407  0.39969787 -0.76096606 -0.98565676]

# %% [markdown]
# #### **Loading with pickle**

# %%
# Load the model from the pickle file
with open('best_model.pkl', 'rb') as f:
    loaded_model_pickle = pickle.load(f)

# Run a prediction on the test set (showing first 5 predictions)
y_pred_pickle = loaded_model_pickle.predict(X_test)
print("Predictions using the loaded pickle model:", y_pred_pickle[:5])
# Out:
# Predictions using the loaded pickle model: [ 0.00555479 -1.18205407  0.39969787 -0.76096606 -0.98565676]

# %% [markdown]
# ### 7.3 Documentation for Future Reference
#
# *   **Save Key Results:**
#
#     *   Store evaluation metrics (MSE, RMSE, MAE, R²) in a table or DataFrame.
#
#     *   Save these results (e.g., as a CSV file) so that you can refer back to them later.

# %%
results_df.to_csv('model_evaluation_metrics.csv', index=True)
print("Model evaluation metrics saved to 'model_evaluation_metrics.csv'.")
# Out:
# Model evaluation metrics saved to 'model_evaluation_metrics.csv'.

# %% [markdown]
# 8\. Conclusion & Insights 🎉
# ----------------------------
#
# ### 8.1 Final Model Ranking
#
# Based on our evaluation metrics (MSE, RMSE, MAE, and R²), the models rank as follows:
#
# 1.  **Random Forest Regression**
#
#     *   **MSE:** 0.08
#
#     *   **RMSE:** 0.28
#
#     *   **MAE:** 0.19
#
#     *   **R²:** 0.93
#
#     _Random Forest emerged as the best performer, capturing complex nonlinear relationships effectively._
#
# 2.  **Ridge Regression** / **Lasso Regression**
#
#     *   **MSE:** 0.10
#
#     *   **RMSE:** 0.31
#
#     *   **MAE:** 0.20
#
#     *   **R²:** 0.91
#
#     _Both regularized linear models performed very similarly, offering robust performance while mitigating overfitting._
#
# 3.  **Support Vector Regression (SVR)**
#
#     *   **MSE:** 0.12
#
#     *   **RMSE:** 0.35
#
#     *   **MAE:** 0.19
#
#     *   **R²:** 0.89
#
#     _SVR provided a balanced performance, although it did not match the predictive power of the tree-based ensemble methods._
#
# 4.  **Polynomial Regression / Decision Tree Regression / K-Nearest Neighbors (KNN)**
#
#     *   **MSE:** 0.15
#
#     *   **RMSE:** 0.39
#
#     *   **MAE:** ~0.28–0.29
#
#     *   **R²:** 0.86
#
#     _These models showed higher errors, suggesting that they may struggle with the underlying data complexities or overfit when not regularized sufficiently._
#
#
# ### 8.2 Key Takeaways & Insights
#
# *   **Ensemble Methods Shine:**
#
#     *   The **Random Forest** model outperformed other approaches. Its ensemble strategy allows it to capture complex, nonlinear relationships and mitigate overfitting, which is particularly valuable in datasets with many features and potential interactions.
#
# *   **Regularization Matters:**
#
#     *   **Ridge** and **Lasso** regression both demonstrated significant improvements over the basic Linear Regression model. Regularization helped control overfitting, especially in a high-dimensional setting with numerous correlated predictors.
#
#     *   **Lasso's** ability to perform feature selection can be beneficial if interpretability is desired, although in this case its performance was similar to Ridge.
#
# *   **Model Complexity vs. Interpretability:**
#
#     *   While more complex models (like Random Forest and SVR) achieved higher predictive accuracy, they may lack the straightforward interpretability of linear models. Depending on your project’s goals, there might be a trade-off between pure performance and the need for a more explainable model.
#
# *   **Dataset Characteristics Influence Model Choice:**
#
#     *   The **Ames Housing Dataset** is rich in features (both continuous and categorical), which provides ample opportunity for feature engineering and regularization.
#
#     *   Models that can effectively manage a high-dimensional feature space and nonlinear interactions, such as Random Forest, tend to perform better on such complex datasets.
#
#     *   Simpler linear models may require more careful feature selection and transformation to achieve competitive performance.
#
# *   **Hyperparameter Tuning & Cross-Validation Are Crucial:**
#
#     *   Systematic tuning (via RandomizedSearchCV or GridSearchCV with k‑fold cross-validation) is essential to optimize each model’s performance.
#
#     *   The improvements in metrics after tuning illustrate how sensitive models can be to hyperparameters, emphasizing the importance of robust model validation.
#
#
# ### **Final Thoughts**
#
# This project not only demonstrates how various regression models perform on a real-world dataset but also highlights the impact of preprocessing, regularization, and hyperparameter tuning on model performance. Your final choice should balance predictive accuracy with interpretability and computational efficiency, depending on the application context.
#
# By following this end-to-end workflow, you've built a robust pipeline that covers everything from data loading and cleaning to advanced model tuning and performance evaluation. Great work! 🚀
